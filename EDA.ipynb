# %%
import pandas as pd

# %%
from ydata_profiling import ProfileReport

# %%
from glob import glob

# %%
glob('/project/scratch/p200631/Silvana/datacenter-challenge/202201/gpu/0000/*.csv')
# Out:
# ['/project/scratch/p200631/Silvana/datacenter-challenge/202201/gpu/0000/31843887425925-r9040233-n911952.csv',
#  '/project/scratch/p200631/Silvana/datacenter-challenge/202201/gpu/0000/48208289474722-r4858666-n386398.csv',
#  '/project/scratch/p200631/Silvana/datacenter-challenge/202201/gpu/0000/89473056875771-r6760045-n386398.csv',
#  '/project/scratch/p200631/Silvana/datacenter-challenge/202201/gpu/0000/26874758244436-r9040233-n851693.csv',
#  '/project/scratch/p200631/Silvana/datacenter-challenge/202201/gpu/0000/23666564800042-r8937440-n851693.csv',
#  '/project/scratch/p200631/Silvana/datacenter-challenge/202201/gpu/0000/48455337309679-r6760045-n830961.csv',
#  '/project/scratch/p200631/Silvana/datacenter-challenge/202201/gpu/0000/85151399193399-r3405251-n208530.csv',
#  '/project/scratch/p200631/Silvana/datacenter-challenge/202201/gpu/0000/28948165934214-r3879907-n208530.csv',
# ...

# %%
df = pd.concat([pd.read_csv(p) for p in glob('/project/scratch/p200631/Silvana/datacenter-challenge/202201/gpu/0000/*.csv')])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df = pd.concat([pd.read_csv(p) for p in glob('/project/scratch/p200631/Silvana/datacenter-challenge/202201/gpu/0000/*.csv')])
#
# Cell In[14], line 1, in <listcomp>(.0)
# ----> 1 df = pd.concat([pd.read_csv(p) for p in glob('/project/scratch/p200631/Silvana/datacenter-challenge/202201/gpu/0000/*.csv')])
#
# ...

# %%
df.shape()

# %%
df.head()
# Out:
#       timestamp  gpu_index  utilization_gpu_pct  utilization_memory_pct  \
# 0  1.618081e+09          0                    0                       0
# 1  1.618081e+09          0                    0                       0
# 2  1.618081e+09          0                    0                       0
# 3  1.618081e+09          0                    0                       0
# 4  1.618081e+09          0                    0                       0
#
#    memory_free_MiB  memory_used_MiB  temperature_gpu  temperature_memory  \
# 0            32510                0               34                  34
# 1            32510                0               34                  34
# 2            32510                0               34                  34
# 3            32510                0               34                  34
# 4            32510                0               34                  34
#
#    power_draw_W  pcie_link_width_current
# 0         26.10                       16
# ...

# %%
profile = ProfileReport(df, title="Profiling Report")

# %%
profile.to_file('report_gpu_metrics.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
